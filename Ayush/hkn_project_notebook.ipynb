# %% [markdown]
# ### Grey Scaling

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("C:/Users/Ayush Sharma/OneDrive/Documents/wlpaper/50878-goku-dragon-ball-super-anime-hd-dragon-ball-4k-5k-8k.jpg")

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
grey_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(grey_img,cmap='grey')
plt.axis('off')
plt.show()
resized_img=cv2.resize(img,(img.shape[1]//2,img.shape[0]//2))
plt.imshow(resized_img,cmap='grey')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Thresholding

# %%
import cv2
import numpy as np

img = cv2.imread("C:/Users/Ayush Sharma/OneDrive/Documents/wlpaper/50878-goku-dragon-ball-super-anime-hd-dragon-ball-4k-5k-8k.jpg")
kernel = np.ones((5, 5), np.uint8)

imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

resized_img = cv2.resize(imgGray, (imgGray.shape[1] // 10, imgGray.shape[0] // 10))
_, binary_image = cv2.threshold(imgGray, 127, 255, cv2.THRESH_BINARY)
_, trunc_image = cv2.threshold(imgGray, 127, 255, cv2.THRESH_TRUNC)
_, tozero_image = cv2.threshold(imgGray, 127, 255, cv2.THRESH_TOZERO)
_, binary_inv_image = cv2.threshold(imgGray, 127, 255, cv2.THRESH_BINARY_INV)

# Display the images
cv2.imshow('Binary Image', binary_image)
cv2.imshow('Trunc Image', trunc_image)
cv2.imshow('TOZERO Image', tozero_image)
cv2.imshow('Binary Inverse Image', binary_inv_image)
cv2.imshow("Gray", imgGray)
cv2.imshow("Original", img)
cv2.imshow("Resized", resized_img)

# Wait for the 'q' key or 'Esc' key to be pressed to exit
while True:
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q') or key == 27:  # 'q' key or 'Esc' key
        break

cv2.destroyAllWindows()

# %% [markdown]
# ### Edge Detection

# %%
edges=cv2.Canny(grey_img,100,200)

# %%
plt.imshow(edges,cmap='grey')
plt.title('Canny Edge Detection')
plt.show()

# %% [markdown]
# ### Preprocessing of data

# %%
import numpy as np 
from sklearn.cluster import KMeans
from PIL import Image

# %%
pixel_values=img.reshape((-1,3))
pixel_values=np.float32(pixel_values)

# %%
k = 3
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(pixel_values)
labels = kmeans.labels_
centers = kmeans.cluster_centers_
centers = np.uint8(centers)

# %%
segmented_image=centers[labels.flatten()]
segmented_image=segmented_image.reshape(img.shape)
plt.imshow(segmented_image)
plt.title(f"segmented image with {k} means")
plt.show()

# %%
for k in [1,2,3]:
    segmented_image=centers[labels.flatten()]
    segmented_image=segmented_image.reshape(img.shape)
    plt.imshow(segmented_image)
    plt.title(f"segmented image with {k} means")
    plt.show()
