# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('D:\mitanshi python\images\shinchan.jpg')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\123\AppData\Local\Temp\ipykernel_7828\3675455996.py:3: SyntaxWarning: invalid escape sequence '\m'
#   img=cv2.imread('D:\mitanshi python\images\shinchan.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img,cmap='gray')
plt.axis('off')
plt.show()

# %%
resized_img=cv2.resize(gray_img,(gray_img.shape[1]//10,gray_img.shape[0]//2))
plt.imshow(resized_img,cmap='gray')
plt.axis("off")
plt.show()

# %%
ret,thresh_binary = cv2.threshold(gray_img ,127, 255,cv2.THRESH_BINARY)
plt.imshow(thresh_binary,'gray',vmin=0, vmax=100)
plt.axis("off")
plt.show()

# %%
ret,thresh_binary_inv = cv2.threshold(gray_img ,127, 255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh_binary_inv,'gray',vmin=0, vmax=100)
plt.axis("off")
plt.show()

# %%
ret,thresh_trunc = cv2.threshold(gray_img ,127, 255,cv2.THRESH_TRUNC)
plt.imshow(thresh_trunc,'gray',vmin=0, vmax=100)
plt.axis("off")
plt.show()

# %%
ret,thresh_tozero = cv2.threshold(gray_img ,127, 255,cv2.THRESH_TOZERO)
plt.imshow(thresh_tozero,'gray',vmin=0, vmax=100)
plt.axis("off")
plt.show()

# %%
ret,thresh_tozero_inv = cv2.threshold(gray_img ,127, 255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh_tozero_inv,'gray',vmin=0, vmax=100)
plt.axis("off")
plt.show()

# %%
edges=cv2.Canny(gray_img,300,500)
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.show()

# %%
import numpy as np
from sklearn.cluster import KMeans
pixel_values=img.reshape((-1,3))
pixel_values=np.float32(pixel_values)
k=4
kMeans=KMeans(n_clusters=k, random_state=42)
kMeans.fit(pixel_values)
labels=kMeans.labels_
centers=kMeans.cluster_centers_
centers=np.uint8(centers)

segmented_image=centers[labels.flatten()]
segmented_image=segmented_image.reshape(img.shape)

plt.imshow(segmented_image)
plt.title(f'Segmented Image with {k} means')
plt.show()
