# %%
import cv2
import matplotlib.pyplot as plt

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
img =cv2.imread('WhatsApp Image 2024-09-19 at 6.56.20 PM.jpeg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
gray_img =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img,cmap='gray')
plt.axis("off")
plt.show()
edges=cv2.Canny(gray_img,300,600)
plt.imshow(edges,cmap='gray')
plt.title('Canny edge detection')
plt.show()
